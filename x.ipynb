# %%
from qiskit import *
from numpy import *
from qiskit.visualization import plot_histogram

# %%
#eintein's measurements
#x
n=4
circuit1=QuantumCircuit(n,n)
circuit1.h(0)
circuit1.cx(0,1)
circuit1.cx(0,2)
circuit1.x(0)
circuit1.cx(1,3)
circuit1.measure(0,0)
# %matplotlib inline
circuit1.draw(output='mpl')

# %%
simulator=Aer.get_backend('qasm_simulator')
result=execute(circuit1,backend=simulator,shots=4096).result()
plot_histogram(result.get_counts(circuit1))

# %%
#xhs
n=4
circuit2=QuantumCircuit(n,n)
circuit2.h(0)
circuit2.cx(0,1)
circuit2.cx(0,2)
circuit2.cx(1,3)
circuit2.x(2)
circuit2.h(2)
circuit2.s(2)
circuit2.measure(2,2)
# %matplotlib inline
circuit2.draw(output='mpl')

# %%
simulator=Aer.get_backend('qasm_simulator')
result1=execute(circuit2,backend=simulator,shots=4096).result()
plot_histogram(result1.get_counts(circuit2))

# %%
#y
n=4
circuit3=QuantumCircuit(n,n)
circuit3.h(0)
circuit3.cx(0,1)
circuit3.cx(0,2)
circuit3.cx(1,3)
circuit3.y(1)
circuit3.measure(1,1)
# %matplotlib inline
circuit3.draw(output='mpl')

# %%
simulator=Aer.get_backend('qasm_simulator')
result1=execute(circuit3,backend=simulator,shots=4096).result()
plot_histogram(result1.get_counts(circuit3))

# %%
#hs
n=4
circuit4=QuantumCircuit(n,n)
circuit4.h(0)
circuit4.cx(0,1)
circuit4.cx(0,2)
circuit4.cx(1,3)
circuit4.h(3)
circuit4.s(3)
circuit4.measure(3,3)
# %matplotlib inline
circuit4.draw(output='mpl')

# %%
simulator=Aer.get_backend('qasm_simulator')
result1=execute(circuit4,backend=simulator,shots=4096).result()
plot_histogram(result1.get_counts(circuit4))

# %%
#bohr's measurements
#hs
n=4
circuit4=QuantumCircuit(n,n)
circuit4.h(0)
circuit4.cx(0,1)
circuit4.cx(0,2)
circuit4.h(0)
circuit4.cx(1,3)
circuit4.s(0)
circuit4.measure(0,0)
# %matplotlib inline
circuit4.draw(output='mpl')

# %%
simulator=Aer.get_backend('qasm_simulator')
result1=execute(circuit4,backend=simulator,shots=4096).result()
plot_histogram(result1.get_counts(circuit4))

# %%
#y
n=4
circuit3=QuantumCircuit(n,n)
circuit3.h(0)
circuit3.cx(0,1)
circuit3.cx(0,2)
circuit3.cx(1,3)
circuit3.y(1)
circuit3.measure(1,1)
# %matplotlib inline
circuit3.draw(output='mpl')

# %%
simulator=Aer.get_backend('qasm_simulator')
result1=execute(circuit3,backend=simulator,shots=4096).result()
plot_histogram(result1.get_counts(circuit3))

# %%
#x
n=4
circuit1=QuantumCircuit(n,n)
circuit1.h(0)
circuit1.cx(0,1)
circuit1.cx(0,2)
circuit1.x(3)
circuit1.cx(1,3)
circuit1.measure(3,3)
# %matplotlib inline
circuit1.draw(output='mpl')

# %%
simulator=Aer.get_backend('qasm_simulator')
result=execute(circuit1,backend=simulator,shots=4096).result()
plot_histogram(result.get_counts(circuit1))

# %%
#xhs
n=4
circuit2=QuantumCircuit(n,n)
circuit2.h(0)
circuit2.cx(0,1)
circuit2.cx(0,2)
circuit2.cx(1,3)
circuit2.x(2)
circuit2.h(2)
circuit2.s(2)
circuit2.measure(2,2)
# %matplotlib inline
circuit2.draw(output='mpl')

# %%
simulator=Aer.get_backend('qasm_simulator')
result1=execute(circuit2,backend=simulator,shots=4096).result()
plot_histogram(result1.get_counts(circuit2))

# %%
print(""" from the results of the histograms:
         neglecting 0 probabilities,
         gates used     einstein values  bohr values  valuematched  
         x                0001           1000              no         
         hs               1000           0001              no
         xhs              0100           0100              yes
         y                0010           0010              yes
    
         xhs and y basis are matching 
         considering no as 0 and yes as 1
         the private code generated will be 0011    
    """)
# Out:
#  from the results of the histograms:
#          neglecting 0 probabilities,
#          gates used     einstein values  bohr values  valuematched
#          x                0001           1000              no
#          hs               1000           0001              no
#          xhs              0100           0100              yes
#          y                0010           0010              yes
#
#          xhs and y basis are matching
#          considering no as 0 and yes as 1
#          the private code generated will be 0011
